# %%
from ecosystem.classes import Ecosystem, Species, AVAILABLE_SPECIES
from ecosystem.utils import user_input_int
from ecosystem.menu import add_new_species, search_species, remove_species

# %%
eco = Ecosystem(10000)
for genus in AVAILABLE_SPECIES:
    eco.add_species(genus)
# Out:
# No species...
# Resources: 10000
# No species...
# Resources: 10000
# No species...
# Resources: 10000
# No species...
# Resources: 10000
# No species...
# Resources: 10000

# %%
print(eco.species_list[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(eco.species_list[0])
#
# IndexError: list index out of range

# %%
Lion = eco.species_list[0]

# %%
print(Lion)
# Out:
# Lion

# %%
Lion.growth_rate
# Out:
# 1.2

# %%
Lion.mutate()
# Out:
# Lion did not mutate.
# 1.2

# %%
Lion.reproduce(1.2)
# Out:
# 48

# %%
eco.run_generation()
# Out:
# No species currently in the ecosystem. Nothing to simulate.
