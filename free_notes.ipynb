# %%
from ecosystem.classes import Ecosystem, Species, AVAILABLE_SPECIES
from ecosystem.utils import user_input_int
from ecosystem.menu import add_new_species, search_species, remove_species

# %%
eco = Ecosystem(10000)
for genus in AVAILABLE_SPECIES:
    eco.add_species(genus)
# Out:
# Lion added to the Ecosystem
# Zebra added to the Ecosystem
# Elephant added to the Ecosystem
# Wolf added to the Ecosystem
# Giraffe added to the Ecosystem

# %%
print(eco.species_list[0])
# Out:
# Lion

# %%
Lion = eco.species_list[0]

# %%
print(Lion)
# Out:
# Lion

# %%
Lion.growth_rate
# Out:
# 1.2

# %%
Lion.mutate()
# Out:
# Lion did not mutate.
# 1.2

# %%
Lion.reproduce(1.2)
# Out:
# 48

# %%
eco.run_generation()
# Out:
# --- Running Generation ---
# Lion did not mutate.
# Zebra did not mutate.
# Elephant did not mutate.
# Wolf did not mutate.
# Giraffe did not mutate.
#
# Food availability = 1
# Total population before = 228
# Total population after reproduction = 532
# Resources consumed = 532
# Remaining resources = 9468

# %%
eco.run_generation()
# Out:
# --- Running Generation ---
# Lion did not mutate.
# Zebra did not mutate.
# Elephant did not mutate.
# Wolf did not mutate.
# Giraffe did not mutate.
#
# Food availability = 1
# Total population before = 532
# Total population after reproduction = 1253
# Resources consumed = 1253
# Remaining resources = 8215
